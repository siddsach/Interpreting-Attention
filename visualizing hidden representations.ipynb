# %%
from sklearn.decomposition import PCA
from sklearn.manifold import MDS
from sklearn.cluster import KMeans
from visualize import *
import torch

# %%
path = 'trained_models/classifier/viz/bestgooglemodel.pt'
data = {}
trained_model = torch.load(path, map_location = lambda storage, loc: storage)
data['words'], data['vals'], data['labels'], data['groundtruth'] = extract(path)

# %%
words = [list(filter(lambda x: x!= '<pad>', a)) for a in data['words']]
words
# Out:
# [['<BOS>', 'hunt', 'continues', '<EOS>'],
#  ['<BOS>', 'international', 'concern', '<EOS>'],
#  ['<BOS>', 'hungry', '.', '<EOS>'],
#  ['<BOS>', 'hot', '.', '<EOS>'],
#  ['<BOS>', 'back', '.', '<EOS>'],
#  ['<BOS>', 'hand', '.', '<EOS>'],
#  ['<BOS>', 'arm', '.', '<EOS>'],
#  ['<BOS>', 'bathroom', '.', '<EOS>'],
#  ['<BOS>', 'leg', '.', '<EOS>'],
#  ['<BOS>', 'cold', '.', '<EOS>'],
#  ['<BOS>', 'thirsty', '.', '<EOS>'],
#  ['<BOS>', 'urinate', '.', '<EOS>'],
#  ['<BOS>', 'no', 'answers', '<EOS>'],
#  ['<BOS>', 'amen', '.', '<EOS>'],
#  ['<BOS>', 'controversial', 'appointments', '<EOS>'],
#  ['<BOS>', 'boycott', 'unfair', '<EOS>'],
#  ['<BOS>', 'personal', 'incomes', '<EOS>'],
#  ['<BOS>', 'praetorian', 'promotion', '<EOS>'],
#  ['<BOS>', 'background', '<EOS>'],
#  ['<BOS>', 'facts', '<EOS>'],
#  ['<BOS>', 'background', '<EOS>'],
#  ['<BOS>', 'facts', '<EOS>'],
#  ['<BOS>', 'trends', '<EOS>'],
#  ['<BOS>', 'mosquitoes', '<EOS>'],
#  ['<BOS>', 'advocate', '<EOS>'],
#  ['<BOS>', 'dialogue', '<EOS>'],
#  ['<BOS>', 'agriculture', '<EOS>'],
#  ['<BOS>', 'transportation', '<EOS>'],
#  ['<BOS>', 'construction', '<EOS>'],
#  ['<BOS>', 'industry', '<EOS>'],
#  ['<BOS>', 'finances', '<EOS>'],
#  ['<BOS>', 'disqualified', '<EOS>'],
#  ['<BOS>', 'they', 'arrived', 'overnight', '.', '<EOS>'],
#  ['<BOS>', '"', 'our', 'cooperation', '?', '<EOS>'],
#  ['<BOS>', 'we', 'are', 'poorly', 'paid', '<EOS>'],
#  ['<BOS>', 'changes', 'in', 'the', 'military', '<EOS>'],
#  ['<BOS>', 'friend', 'of', 'the', 'guerrillas', '<EOS>'],
#  ['<BOS>', 'the', 'president', 'to', 'court', '<EOS>'],
#  ['<BOS>', 'the', 'fan', 'is', 'manipulated', '<EOS>'],
#  ['<BOS>', 'experts', "'", 'opinion', '<EOS>'],
#  ['<BOS>', 'apparently', 'not', '.', '<EOS>'],
#  ['<BOS>', 'stop', 'the', 'circus', '<EOS>'],
#  ['<BOS>', 'promises', 'are', 'cheap', '<EOS>'],
#  ['<BOS>', 'an', 'example', '?', '<EOS>'],
#  ['<BOS>', 'neutral', 'country', '.', '<EOS>'],
#  ['<BOS>', '"', 'enough', '.', '<EOS>'],
#  ['<BOS>', 'the', 'second', 'front', '<EOS>'],
#  ['<BOS>', 'slice', 'of', 'u.s.', '<EOS>'],
#  ['<BOS>', 'bush', 'stands', 'firm', '<EOS>'],
#  ['<BOS>', 'you', 'bet', '.', '<EOS>'],
#  ['<BOS>', 'zambia', 'hails', 'result', '<EOS>'],
#  ['<BOS>', 'iv', 'hurts', '.', '<EOS>'],
#  ['<BOS>', 'craner', 'okay', '.', '<EOS>'],
#  ['<BOS>', 'craner', 'yes', '.', '<EOS>'],
#  ['<BOS>', 'prices', 'and', 'rates', '<EOS>'],
#  ['<BOS>', 'external', 'economic', 'activity', '<EOS>'],
#  ['<BOS>', 'criticism', 'of', 'government', '<EOS>'],
#  ['<BOS>', 'internal', 'discipline', '<EOS>'],
#  ['<BOS>', 'cancellation', 'insurance', '<EOS>'],
#  ['<BOS>', 'shameful', "'", '<EOS>'],
#  ['<BOS>', '1999', 'plans', '<EOS>'],
#  ['<BOS>', 'continuing', 'effect', '<EOS>'],
#  ['<BOS>', 'taiwan', 'relieved', '<EOS>'],
#  ['<BOS>', 'modern', 'barnstormers', '<EOS>'],
#  ['<BOS>', 'what', 'is', 'nonwasp', 'humanity', '?', '<EOS>'],
#  ['<BOS>', 'those', 'who', 'use', 'the', 'imf', '<EOS>'],
#  ['<BOS>', 'this', 'is', 'useless', 'sophistry', '.', '<EOS>'],
#  ['<BOS>', 'where', 'is', 'the', 'evidence', '?', '<EOS>'],
#  ['<BOS>', '"', 'illegal', 'combatants', '"', '<EOS>'],
#  ['<BOS>', 'the', 'obvious', 'is', 'incredible', '<EOS>'],
#  ['<BOS>', 'it', 'is', 'dangerous', '!', '<EOS>'],
#  ['<BOS>', 'some', 'particularly', 'financial', 'choices', '<EOS>'],
#  ['<BOS>', 'fear', 'of', 'grim', 'years', '<EOS>'],
#  ['<BOS>', 'negotiation', 'was', 'stymied', '.', '<EOS>'],
#  ['<BOS>', "c'wealth", 'mission', 'conduct', 'questionable', '<EOS>'],
#  ['<BOS>', 'more', 'political', 'than', 'economic', '<EOS>'],
#  ['<BOS>', 'turover', 'accused', 'mme', '.', '<EOS>'],
#  ['<BOS>', 'the', 'vitriol', 'continues', '.', '<EOS>'],
#  ['<BOS>', 'western', 'governments', 'disagree', '.', '<EOS>'],
#  ['<BOS>', 'talk', 'about', 'clueless', '.', '<EOS>'],
#  ['<BOS>', 'everyone', 'else', 'loses', '.', '<EOS>'],
#  ['<BOS>', 'africa', "'s", 'grand', 'bargain', '<EOS>'],
#  ['<BOS>', 'zimbabwean', 'presidential', 'vote', 'begins', '<EOS>'],
#  ['<BOS>', 'most', 'debt', 'in', 'dollars', '<EOS>'],
#  ['<BOS>', 'chavez', "'s", 'last', 'day', '<EOS>'],
#  ['<BOS>', "'", 'n', 'space', '?', '<EOS>'],
#  ['<BOS>', 'guantanamo', "'s", 'unhappy', 'campers', '<EOS>'],
#  ['<BOS>', 'usjapan', 'climate', 'talks', 'end', '<EOS>'],
#  ['<BOS>', 'head', 'down', '!', '"', '<EOS>'],
#  ['<BOS>', '"', 'shut', 'up', '!', '<EOS>'],
#  ['<BOS>', 'excerpts', 'from', 'the', 'briefing', '<EOS>'],
#  ['<BOS>', 'what', "'s", 'different', '?', '<EOS>'],
#  ['<BOS>', 'details', 'are', 'awaited', '.', '<EOS>'],
#  ['<BOS>', 'police', 'are', 'investigating', '.', '<EOS>'],
#  ['<BOS>', 'what', 'is', 'europe', '.', '<EOS>'],
#  ['<BOS>', 'gross', 'domestic', 'product', 'gdp', '<EOS>'],
#  ['<BOS>', 'u.s.', 'accuses', 'mugabe', 'of', 'intimidation', '<EOS>'],
#  ['<BOS>', 'zimbabwe', 'suspended', 'for', 'rigging', 'election', '<EOS>'],
#  ['<BOS>', 'aussies', 'see', 'us', 'double', 'standard', '<EOS>'],
#  ['<BOS>', 'but', 'we', 'are', 'scared', '.', '<EOS>'],
#  ['<BOS>', 'no', 'more', 'austerity', 'plans', '!', '<EOS>'],
#  ['<BOS>', '"', 'it', "'s", 'shameful', '.', '<EOS>'],
#  ['<BOS>', 'help', 'once', 'things', 'stabilized', '.', '<EOS>'],
#  ['<BOS>', 'israel', 'is', 'at', 'war', '.', '<EOS>'],
#  ['<BOS>', 'warning', 'lights', 'are', 'flashing', '.', '<EOS>'],
#  ['<BOS>', 'guantanamo', 'to', 'hold', 'terror', 'prisoners', '<EOS>'],
#  ['<BOS>', 'subhead', '  ', 'lawmakers', 'boycott', 'event', '<EOS>'],
#  ['<BOS>', 'argentina', 'is', 'now', 'broke', '.', '<EOS>'],
#  ['<BOS>', '"', 'it', 'was', 'horrible', '.', '<EOS>'],
#  ['<BOS>', 'mugabe', 'rigged', 'zimbabwe', 'polls', 'britain', '<EOS>'],
#  ['<BOS>', 'mugabe', 'wins', 'zimbabwe', 'presidential', 'polls', '<EOS>'],
#  ['<BOS>', 'veni', ',', 'vidi', ',', 'venezuela', '<EOS>'],
#  ['<BOS>', 'the', 'hospitality', 'ends', 'there', '.', '<EOS>'],
#  ['<BOS>', 'argentina', 'braces', 'for', 'currency', 'fall', '<EOS>'],
#  ['<BOS>', 'six', 'days', 'that', 'shook', 'venezuela', '<EOS>'],
#  ['<BOS>', 'harsh', 'detention', 'for', 'afghan', 'prisoners', '<EOS>'],
#  ['<BOS>', 'mugabe', 'wins', 'despite', 'biased', 'propaganda', '<EOS>'],
#  ['<BOS>', 'this', 'is', 'most', 'unfortunate', '.', '<EOS>'],
#  ['<BOS>', 'most', 'of', 'them', 'sleep', '.', '<EOS>'],
#  ['<BOS>', '72', 'hours', 'at', 'camp', 'xray', '<EOS>'],
#  ['<BOS>', 'jordan', 'to', 'sign', 'kyoto', 'protocol', '<EOS>'],
#  ['<BOS>',
#   'navy',
#   'officer',
#   'balances',
#   'religious',
#   'responsibilities',
#   '<EOS>'],
#  ['<BOS>', 'what', 'are', 'you', 'asking', '?', '<EOS>'],
#  ['<BOS>', 'cabinet', 'ok', "'s", 'ratification', 'draft', '<EOS>'],
#  ['<BOS>', 'and', 'did', ',', 'spectacularly', '.', '<EOS>'],
#  ['<BOS>', 'privatization', 'earned', '40', 'billion', '.', '<EOS>'],
#  ['<BOS>', '"', 'mr.', 'tsvangirai', 'asked', '.', '<EOS>'],
#  ['<BOS>', 'police', 'have', 'taken', 'cognizance', '.', '<EOS>'],
#  ['<BOS>', 'craner', 'we', "'re", 'getting', 'there', '.', '<EOS>'],
#  ['<BOS>', 'craner', 'what', 'is', 'different', 'currently', '?', '<EOS>'],
#  ['<BOS>', 'q', 'what', 'about', 'saudi', 'arabia', '?', '<EOS>'],
#  ['<BOS>', 'mugabe', 'victory', 'leaves', 'west', 'in', 'tatters', '<EOS>'],
#  ['<BOS>', 'china', 'criticizes', 'us', 'human', 'rights', 'report', '<EOS>'],
#  ['<BOS>', 'police', 'have', 'registered', 'a', 'case', '.', '<EOS>'],
#  ['<BOS>', 'two', 'points', 'must', 'be', 'made', '.', '<EOS>'],
#  ['<BOS>', 'it', 'is', 'its', 'national', 'policy', '.', '<EOS>'],
#  ['<BOS>', 'zanu', 'pf', 'readies', 'for', 'war', '<EOS>'],
#  ['<BOS>', 'it', 'demands', 'immediate', 'action', '.', '<EOS>'],
#  ['<BOS>', 'there', 'is', 'an', 'entire', '.', '<EOS>'],
#  ['<BOS>', 'sumitomo', 'construction', 'ended', 'unchanged', '.', '<EOS>'],
#  ['<BOS>', 'now', 'they', 'are', 'not', '.', '<EOS>'],
#  ['<BOS>', 'the', 'end', 'and', 'the', 'means', '<EOS>'],
#  ['<BOS>', 'criticism', 'from', 'the', 'red', 'cross', '<EOS>'],
#  ['<BOS>', 'settlers', 'have', 'taken', 'palestine', 'hostage', '<EOS>'],
#  ['<BOS>', 'the', 'reduction', 'level', 'varies', '.', '<EOS>'],
#  ['<BOS>', 'the', 'discontent', 'of', 'the', 'environmentalists', '<EOS>'],
#  ['<BOS>', 'this', 'is', 'not', 'acceptable', '.', '<EOS>'],
#  ['<BOS>', 'should', 'one', 'be', 'surprised', '?', '<EOS>'],
#  ['<BOS>', 'no', 'ransom', 'was', 'paid', '.', '<EOS>'],
#  ['<BOS>', '"', 'that', "'s", 'ridiculous', '.', '<EOS>'],
#  ['<BOS>', 'he', 'has', 'one', 'daughter', '.', '<EOS>'],
#  ['<BOS>', 'albright', 'first', 'to', 'launch', 'attack', '<EOS>'],
#  ['<BOS>', 'we', 'welcome', 'it', '.', '"', '<EOS>'],
#  ['<BOS>', '"', 'there', 'you', 'see', '!', '<EOS>'],
#  ['<BOS>', 'paratroopers', 'return', 'chavez', 'to', 'power', '<EOS>'],
#  ['<BOS>', '"', 'it', "'s", 'propaganda', '.', '<EOS>'],
#  ['<BOS>', 'oh', ',', 'the', 'horror', '.', '<EOS>'],
#  ['<BOS>', 'call', 'it', 'club', 'gitmo', '.', '<EOS>'],
#  ['<BOS>', 'canadian', 'to', 'join', 'endeavour', 'crew', '<EOS>'],
#  ['<BOS>', 'why', 'kyoto', 'is', 'a', 'ripoff', '<EOS>'],
#  ['<BOS>', 'his', 'crewmates', 'were', 'two', 'russians', '.', '<EOS>'],
#  ['<BOS>', 'pyongyang', 'has', 'yet', 'to', 'respond', '.', '<EOS>'],
#  ['<BOS>', 'russia', 'disagrees', 'with', 'axis', "'", 'remark', '<EOS>'],
#  ['<BOS>', 'that', "'s", 'a', 'fair', 'deal', '.', '<EOS>'],
#  ['<BOS>', 'the', 'base', 'is', 'extremely', 'isolated', '.', '<EOS>'],
#  ['<BOS>', 'zimbabwe', "'s", 'president', 'is', 'sworn', 'in', '<EOS>'],
#  ['<BOS>',
#   'florida',
#   'astronauts',
#   'repair',
#   'space',
#   'station',
#   'wings',
#   '<EOS>'],
#  ['<BOS>', 'it', "'s", 'a', 'ripple', 'effect', '.', '<EOS>'],
#  ['<BOS>', 'future', 'us', 'modules', 'were', 'redpenciled', '.', '<EOS>'],
#  ['<BOS>', 'the', 'country', 'is', 'in', 'shellshock', '.', '<EOS>'],
#  ['<BOS>', 'zimbabwe', 'vote', 'a', 'test', 'of', 'patience', '<EOS>'],
#  ['<BOS>', 'this', 'is', 'our', 'future', '.', '"', '<EOS>'],
#  ['<BOS>',
#   'taiwan',
#   'caucus',
#   'a',
#   'us',
#   'provocation',
#   'commentary',
#   '<EOS>'],
#  ['<BOS>', 'u.s.', 'begins', 'first', 'airlift', 'of', 'prisoners', '<EOS>'],
#  ['<BOS>',
#   'u.s.',
#   'refuses',
#   'to',
#   'recognize',
#   'mugabe',
#   'government',
#   '<EOS>'],
#  ['<BOS>',
#   'finance',
#   'minister',
#   'of',
#   'argentina',
#   'resigns',
#   'post',
#   '<EOS>'],
#  ['<BOS>',
#   'u.s.',
#   'closely',
#   'monitoring',
#   'situation',
#   'in',
#   'argentina',
#   '<EOS>'],
#  ['<BOS>', 'washington', 'joined', 'in', 'the', 'bailout', '.', '<EOS>'],
#  ['<BOS>', "'", 'are', 'they', 'kennels', '?', "'", '<EOS>'],
#  ['<BOS>', 'some', 'also', 'wore', 'leg', 'shackles', '.', '<EOS>'],
#  ['<BOS>', 'many', 'fear', 'violence', 'after', 'zimbabwe', 'vote', '<EOS>'],
#  ['<BOS>', 'mugabe', 'won', 'polls', 'unfairly', 'says', 'west', '<EOS>'],
#  ['<BOS>', 'a', 'navy', 'helicopter', 'whirls', 'overhead', '.', '<EOS>'],
#  ['<BOS>', 'sick', ',', 'will', 'throw', 'up', '.', '<EOS>'],
#  ['<BOS>', 'they', 'refused', 'to', 'allow', 'cameras', '.', '<EOS>'],
#  ['<BOS>', 'rights', 'groups', 'cried', 'inhumane', 'treatment', '.', '<EOS>'],
#  ['<BOS>', 'do', 'you', 'keep', 'the', 'secret', '?', '<EOS>'],
#  ['<BOS>', 'club', 'fed', 'and', 'our', 'invisible', 'troops', '<EOS>'],
#  ['<BOS>', 'charity', 'should', 'begin', 'at', 'home', '.', '<EOS>'],
#  ['<BOS>', 'pakistan', 'rejects', 'us', 'human', 'rights', 'report', '<EOS>'],
#  ['<BOS>', 'police', 'had', 'no', 'immediate', 'comment', '.', '<EOS>'],
#  ['<BOS>', 'us', 'human', 'rights', 'report', 'invites', 'scorn', '<EOS>'],
#  ['<BOS>', 'this', 'initiative', 'is', 'not', 'partial', '.', '<EOS>'],
#  ['<BOS>', 'it', 'has', 'now', 'taken', 'place', '.', '<EOS>'],
#  ['<BOS>', 'everyone', 'opposes', 'and', 'rejects', 'it', '.', '<EOS>'],
#  ['<BOS>', 'the', 'gunmen', 'let', 'her', 'go', '.', '<EOS>'],
#  ['<BOS>', 'the', 'concern', 'now', 'is', 'security', '.', '<EOS>'],
#  ['<BOS>', 'his', 'dynamism', 'is', 'an', 'asset', '.', '<EOS>'],
#  ['<BOS>', 'the', 'answer', 'should', 'be', 'negative', '.', '<EOS>'],
#  ['<BOS>', 'chavez', "'s", 'whereabouts', 'were', 'unclear', '.', '<EOS>'],
#  ['<BOS>', 'bse', 'case', 'reported', 'in', 'southwestern', 'france', '<EOS>'],
#  ['<BOS>', 'it', 'is', 'certainly', 'playing', 'games', '.', '<EOS>'],
#  ['<BOS>', 'herein', 'lies', 'his', 'wicked', 'intention', '.', '<EOS>'],
#  ['<BOS>', 'but', 'we', 'had', 'no', 'choice', '.', '<EOS>'],
#  ['<BOS>',
#   'tajikistan',
#   'drugbusting',
#   'hampered',
#   'by',
#   'obsolete',
#   'equipment',
#   '<EOS>'],
#  ['<BOS>', 'the', 'zimbabwean', 'minister', 'did', 'this', '.', '<EOS>'],
#  ['<BOS>', 'the', 'two', 'have', 'similar', 'symptoms', '.', '<EOS>'],
#  ['<BOS>', 'little', 'is', 'clear', ',', 'however', '.', '<EOS>'],
#  ['<BOS>',
#   'israeli',
#   'parliament',
#   'speaker',
#   'slams',
#   'zionist',
#   'occupation',
#   '<EOS>'],
#  ['<BOS>', 'europe', 'to', 'tax', 'israeli', 'settlement', 'goods', '<EOS>'],
#  ['<BOS>', 'endeavour', 'shuttle', 'to', 'return', 'on', 'monday', '<EOS>'],
#  ['<BOS>',
#   'shuttle',
#   'atlantis',
#   'thunders',
#   'toward',
#   'space',
#   'station',
#   '<EOS>'],
#  ['<BOS>', 'soldiers', 'unite', 'to', 'defend', 'camp', 'xray', '<EOS>'],
#  ['<BOS>', 'staff', 'sgt', 'webster', 'was', 'frustrated', '.', '<EOS>'],
#  ['<BOS>', 'the', 'target', 'capacity', 'is', '2,000', '.', '<EOS>'],
#  ['<BOS>', 'camp', 'xray', 'or', 'club', 'med', '?', '<EOS>'],
#  ['<BOS>', '"', 'the', 'clock', 'is', 'ticking', '.', '<EOS>'],
#  ['<BOS>', 'they', 'just', 'wanted', 'more', 'consultations', '.', '<EOS>'],
#  ['<BOS>', 'let', "'s", 'remember', 'that', '.', '"', '<EOS>'],
#  ['<BOS>', 'canadarm2', 'lays', 'track', 'for', 'space', 'railway', '<EOS>'],
#  ['<BOS>', 'the', 'party', 'also', 'controls', 'congress', '.', '<EOS>'],
#  ['<BOS>', '"', 'obviously', 'i', "'m", 'worried', '.', '<EOS>'],
#  ['<BOS>', 'but', 'where', 'is', 'that', 'management', '?', '<EOS>'],
#  ['<BOS>', 'they', 'will', 'stay', 'aboard', 'until', 'may.', '<EOS>'],
#  ['<BOS>', 'now', 'that', 'really', 'would', 'be', 'cruel', '.', '<EOS>'],
#  ['<BOS>',
#   'officials',
#   'bristle',
#   'at',
#   'us',
#   'human',
#   'rights',
#   'report',
#   '<EOS>'],
#  ['<BOS>',
#   'or',
#   'do',
#   'you',
#   'breach',
#   'religious',
#   'confidentiality',
#   '?',
#   '<EOS>'],
#  ['<BOS>', 'craner', 'how', 'do', 'you', 'know', 'that', '?', '<EOS>'],
#  ['<BOS>', 'craner', 'they', 'do', "n't", 'have', 'elections', '.', '<EOS>'],
#  ['<BOS>', 'q', 'who', 'is', 'the', 'worst', 'violator', '?', '<EOS>'],
#  ['<BOS>', 'q', 'but', 'i', 'heard', 'this', 'before', '.', '<EOS>'],
#  ['<BOS>',
#   'us',
#   'begins',
#   'flying',
#   'afghan',
#   'prisoners',
#   'to',
#   'cuba',
#   '<EOS>'],
#  ['<BOS>',
#   'dushanbe',
#   'meeting',
#   'discusses',
#   'helping',
#   'afghan',
#   'northern',
#   'alliance',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'job',
#   'market',
#   'and',
#   'the',
#   'demographic',
#   'situation',
#   '<EOS>'],
#  ['<BOS>',
#   'investments',
#   'came',
#   'in',
#   'from',
#   '112',
#   'countries',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'the', 'first', 'group', 'is', 'the', 'media', '.', '<EOS>'],
#  ['<BOS>',
#   'mugabe',
#   'must',
#   'be',
#   'confronted',
#   'with',
#   'constitution',
#   'issue',
#   '<EOS>'],
#  ['<BOS>',
#   'no',
#   'casualties',
#   'were',
#   'registered',
#   'among',
#   'policemen',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'moscow', 'time', '0520', 'gmt', 'on', 'friday', '.', '<EOS>'],
#  ['<BOS>', 'its', 'first', 'target', 'is', 'the', 'moon', '.', '<EOS>'],
#  ['<BOS>',
#   'iraqi',
#   'and',
#   'afghan',
#   'immigrants',
#   'followed',
#   'them',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'sebi', 'also', 'gave', 'out', 'certificates', '.', '<EOS>'],
#  ['<BOS>', 'adjustment', 'index', 'will', 'be', 'new', 'variable', '<EOS>'],
#  ['<BOS>', 'how', 'does', 'this', 'affect', 'brazil', '?', '<EOS>'],
#  ['<BOS>',
#   'taiwanese',
#   'officials',
#   'are',
#   'nonetheless',
#   'concerned',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'you', 'can', 'count', 'on', 'that', '.', '<EOS>'],
#  ['<BOS>', 'their', 'identity', 'was', 'not', 'available', '.', '<EOS>'],
#  ['<BOS>', 'the', 'encounter', 'was', 'still', 'continuing', '.', '<EOS>'],
#  ['<BOS>', 'many', 'had', 'disappeared', 'without', 'trace', '.', '<EOS>'],
#  ['<BOS>', 'he', 'pursued', 'an', 'independent', 'policy', '.', '<EOS>'],
#  ['<BOS>', 'what', 'preceded', 'the', 'kyoto', 'protocol', '?', '<EOS>'],
#  ['<BOS>', 'what', 'does', 'this', 'lead', 'to', '?', '<EOS>'],
#  ['<BOS>', 'no', 'one', 'will', 'be', 'well', 'off', '<EOS>'],
#  ['<BOS>', 'torpedo', 'strength', 'is', 'also', 'insufficient', '.', '<EOS>'],
#  ['<BOS>',
#   'pursue',
#   'the',
#   'international',
#   'climate',
#   'negotiations',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'implementation', 'of', 'the', 'kyoto', 'protocol', '.', '<EOS>'],
#  ['<BOS>', 'us', 'and', 'uk', 'criticise', 'mugabe', "'s", 'victory', '<EOS>'],
#  ['<BOS>',
#   'space',
#   'station',
#   "'s",
#   'railcar',
#   'slightly',
#   'off',
#   'track',
#   '<EOS>'],
#  ['<BOS>',
#   'nasa',
#   'blamed',
#   'the',
#   'problem',
#   'on',
#   'weightlessness',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'the', 'detainees', 'are', 'washing', 'every', 'day', '.', '<EOS>'],
#  ['<BOS>', 'a', 'few', 'call', 'to', 'each', 'other', '.', '<EOS>'],
#  ['<BOS>', '"', 'our', 'guys', 'are', 'pretty', 'dirty', '.', '<EOS>'],
#  ['<BOS>', 'new', 'crew', 'settles', 'in', 'at', 'space', 'station', '<EOS>'],
#  ['<BOS>', 'and', 'it', 'can', 'act', 'unilaterally', '.', '"', '<EOS>'],
#  ['<BOS>', '"', 'no', 'murderer', 'will', 'go', 'unpunished', '.', '<EOS>'],
#  ['<BOS>', 'but', 'jean', 'chretien', 'is', 'not', 'worried', '.', '<EOS>'],
#  ['<BOS>', 'they', 'should', 'be', 'brought', 'to', 'justice', '.', '<EOS>'],
#  ['<BOS>', 'but', 'the', 'budget', 'was', 'a', 'disaster', '.', '<EOS>'],
#  ['<BOS>',
#   'axis',
#   'of',
#   'evil',
#   "'",
#   'charge',
#   'raises',
#   'questions',
#   '<EOS>'],
#  ['<BOS>', 'israel', 'seized', 'the', 'shipment', 'jan.', '3', '.', '<EOS>'],
#  ['<BOS>',
#   'no',
#   'updated',
#   'figure',
#   'was',
#   'available',
#   'thursday',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'china', 'slams', 'us', 'arms', 'sales', 'to', 'taiwan', '<EOS>'],
#  ['<BOS>', 'new', 'man', 'for', 'a', 'new', 'nasa', 'mission', '<EOS>'],
#  ['<BOS>', 'tokyo', 'irked', 'by', 'us', 'stance', 'on', 'kyoto', '<EOS>'],
#  ['<BOS>', 'the', 'weirdness', 'does', "n't", 'end', 'there', '.', '<EOS>'],
#  ['<BOS>',
#   'perhaps',
#   'the',
#   'international',
#   'community',
#   'is',
#   'right',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'ministry',
#   'criticizes',
#   "'",
#   'odious',
#   "'",
#   'u.s.',
#   'report',
#   '<EOS>'],
#  ['<BOS>', 'blair', 'not', 'happy', 'with', 'new', 'green', 'deal', '<EOS>'],
#  ['<BOS>', 'in', 'fact', ',', 'quite', 'the', 'contrary', '.', '<EOS>'],
#  ['<BOS>',
#   'mugabe',
#   'predicts',
#   'victory',
#   'in',
#   'zimbabwe',
#   "'s",
#   'election',
#   '<EOS>'],
#  ['<BOS>',
#   'cabello',
#   'promises',
#   'to',
#   'restore',
#   'constitutional',
#   'order',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'the', 'strike', 'is', 'later', 'made', 'indefinite', '.', '<EOS>'],
#  ['<BOS>',
#   'angry',
#   'at',
#   'vote',
#   ',',
#   'commonwealth',
#   'bars',
#   'zimbabwe',
#   '<EOS>'],
#  ['<BOS>', 'is', 'it', 'inhumane', 'to', 'do', 'that', '?', '<EOS>'],
#  ['<BOS>', 'the', 'fall', 'and', 'rise', 'of', 'hugo', 'chavez', '<EOS>'],
#  ['<BOS>', '"', 'you', "'re", 'doing', 'good', '.', '"', '<EOS>'],
#  ['<BOS>', 'he', 'ca', "n't", 'make', 'a', 'plan', '.', '<EOS>'],
#  ['<BOS>', 'still', ',', 'things', 'could', 'be', 'worse', '.', '<EOS>'],
#  ['<BOS>',
#   'the',
#   'ecologicaleconomic',
#   'meaning',
#   'of',
#   'the',
#   'kyoto',
#   'protocol',
#   '<EOS>'],
#  ['<BOS>',
#   'all',
#   'of',
#   'our',
#   'activities',
#   'are',
#   'ruining',
#   'nature',
#   '<EOS>'],
#  ['<BOS>', 'those', 'in', 'attendance', 'did', 'not', 'argue', '.', '<EOS>'],
#  ['<BOS>', 'this', 'is', 'an', 'issue', 'of', 'will', '.', '<EOS>'],
#  ['<BOS>',
#   'what',
#   'followed',
#   'was',
#   'the',
#   'afghanistan',
#   'war',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'fines', 'for', 'exceeding', 'the', 'quota', 'limit', '.', '<EOS>'],
#  ['<BOS>',
#   'spain',
#   'believes',
#   'camp',
#   'xray',
#   'prisoners',
#   'treated',
#   'humanely',
#   '<EOS>'],
#  ['<BOS>',
#   'brazil',
#   "'s",
#   'objectives',
#   'were',
#   'fully',
#   'achieved',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'it', 'certainly', 'is', 'not', 'any', 'more', '.', '<EOS>'],
#  ['<BOS>',
#   'this',
#   'spells',
#   'serious',
#   'trouble',
#   'for',
#   'bush',
#   '.',
#   '<EOS>'],
#  ['<BOS>', '"', 'there', 'are', 'still', 'no', 'regulations', '.', '<EOS>'],
#  ['<BOS>', 'it', 'had', 'to', 'do', 'with', 'chechnya', '.', '<EOS>'],
#  ['<BOS>',
#   'justice',
#   'always',
#   'finds',
#   'support',
#   'and',
#   'sympathy',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'but', 'those', 'were', 'the', 'us', 'needs', '.', '<EOS>'],
#  ['<BOS>', 'it', 'is', 'not', 'evolving', 'in', 'coolum', '.', '<EOS>'],
#  ['<BOS>',
#   'mkapa',
#   'says',
#   'punitive',
#   'action',
#   'against',
#   'zim',
#   'premature',
#   '<EOS>'],
#  ['<BOS>', 'we', 'have', 'a', 'very', 'risky', 'scenario', '.', '<EOS>'],
#  ['<BOS>',
#   'concern',
#   'has',
#   'spread',
#   'to',
#   'brazilian',
#   'legislators',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'no', 'one', 'has', 'yet', 'been', 'arrested', '.', '<EOS>'],
#  ['<BOS>',
#   'that',
#   'statement',
#   'immediately',
#   'caused',
#   'extensive',
#   'controversy',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'the', 'persons', 'wanted', 'to', 'escape', 'abroad', '.', '<EOS>'],
#  ['<BOS>',
#   'however',
#   ',',
#   'bush',
#   'is',
#   'greatly',
#   'miscalculating',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'how', 'accustomed', 'they', 'are', 'to', 'trickery', '!', '<EOS>'],
#  ['<BOS>', 'it', 'was', 'surely', 'not', 'just', 'rhetoric', '.', '<EOS>'],
#  ['<BOS>', 'it', 'is', 'a', 'crime', 'against', 'humanity', '.', '<EOS>'],
#  ['<BOS>',
#   'kazakh',
#   'president',
#   'optimistic',
#   'about',
#   'future',
#   'of',
#   'cis',
#   '<EOS>'],
#  ['<BOS>', 'no', 'doubt', 'blair', 'will', 'fight', 'on', '.', '<EOS>'],
#  ['<BOS>', 'it', 'can', 'not', 'make', 'more', 'concessions', '.', '<EOS>'],
#  ['<BOS>',
#   'this',
#   'may',
#   'be',
#   'convenient',
#   'for',
#   'washington',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'annan',
#   'welcomes',
#   'restitution',
#   'of',
#   'constitution',
#   'in',
#   'venezuela',
#   '<EOS>'],
#  ['<BOS>',
#   'two',
#   'russian',
#   'cosmonauts',
#   'to',
#   'conduct',
#   'space',
#   'walk',
#   '<EOS>'],
#  ['<BOS>',
#   'endeavour',
#   'shuttle',
#   'to',
#   'be',
#   'launched',
#   'to',
#   'iss',
#   '<EOS>'],
#  ['<BOS>',
#   'sen.',
#   'aquilino',
#   'pimentel',
#   'expressed',
#   'the',
#   'same',
#   'apprehension',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'this',
#   'is',
#   'neocolonialism',
#   'and',
#   'economic',
#   'colonialism',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'west', 'aims', "'", 'to', 'prop', 'up', 'mdc', "'", '<EOS>'],
#  ['<BOS>',
#   'production',
#   'in',
#   'the',
#   'textile',
#   'industry',
#   'grew',
#   '12',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'wholesale',
#   'and',
#   'retail',
#   'trade',
#   ',',
#   'the',
#   'restaurant',
#   'industry',
#   '<EOS>'],
#  ['<BOS>',
#   'serdyuk',
#   'surrendered',
#   'to',
#   'the',
#   'police',
#   'at',
#   '820',
#   'a.m.',
#   '<EOS>'],
#  ['<BOS>',
#   'other',
#   'than',
#   'that',
#   ',',
#   'nothing',
#   'will',
#   'count',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'it',
#   'is',
#   'then',
#   'converted',
#   'back',
#   'to',
#   'electricity',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'eventually',
#   ',',
#   'the',
#   'h2a',
#   'rocket',
#   'was',
#   'developed',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'those',
#   'with',
#   'two',
#   'children',
#   'mostly',
#   'undergo',
#   'sterilization',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'they',
#   'oppose',
#   'the',
#   'commemoration',
#   'of',
#   'military',
#   'uprisings',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'therefore',
#   ',',
#   'they',
#   'no',
#   'longer',
#   'have',
#   'command',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'united',
#   'states',
#   'possesses',
#   'solid',
#   'evidence',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'your', 'hypothesis', 'is', 'not', 'irrelevant', '.', '"', '<EOS>'],
#  ['<BOS>',
#   'taiwan',
#   'will',
#   'follow',
#   'suit',
#   'shortly',
#   'after',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'bad',
#   'government',
#   'management',
#   'complicates',
#   'any',
#   'situation',
#   '.',
#   '<EOS>'],
#  ['<BOS>', '"', 'la', 'plata', '"', 'or', 'social', 'rebellion', '<EOS>'],
#  ['<BOS>', 'a', 'total', 'of', '21', 'laws', 'prepared', '.', '<EOS>'],
#  ['<BOS>',
#   'international',
#   'pressure',
#   'is',
#   'on',
#   'israel',
#   'again',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'neighbors',
#   'lack',
#   'an',
#   'extradition',
#   'treaty',
#   '.',
#   '<EOS>'],
#  ['<BOS>', '"', 'definitely', ',', '"', 'he', 'said', '.', '<EOS>'],
#  ['<BOS>',
#   'space',
#   'remains',
#   'a',
#   'russian',
#   'national',
#   'priority',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'president',
#   'bush',
#   'will',
#   'visit',
#   'china',
#   'soon',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'this', 'is', 'really', 'an', 'unwise', 'idea', '.', '<EOS>'],
#  ['<BOS>',
#   'kazakhstan',
#   "'s",
#   'main',
#   'seaport',
#   'does',
#   'brisk',
#   'business',
#   '<EOS>'],
#  ['<BOS>', 'it', 'will', 'speak', 'in', 'its', 'report', '.', '<EOS>'],
#  ['<BOS>',
#   'but',
#   'taiwanese',
#   'officials',
#   'are',
#   'nonetheless',
#   'concerned',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'america',
#   'always',
#   'follows',
#   'its',
#   'interests',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'sharon', 'is', 'a', 'master', 'of', 'escalation', '.', '<EOS>'],
#  ['<BOS>', '"', 'there', 'were', 'deaths', 'in', 'custody', '.', '<EOS>'],
#  ['<BOS>',
#   'methane',
#   "'s",
#   'contribution',
#   'is',
#   '15',
#   'percent',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'russia',
#   "'s",
#   'obligations',
#   'under',
#   'the',
#   'kyoto',
#   'protocol',
#   '<EOS>'],
#  ['<BOS>',
#   'africa',
#   ',',
#   'west',
#   'split',
#   'over',
#   'mugabe',
#   "'s",
#   'win',
#   '<EOS>'],
#  ['<BOS>',
#   'tiny',
#   'debris',
#   'outside',
#   'space',
#   'station',
#   'halts',
#   'shuttle',
#   'launch',
#   '<EOS>'],
#  ['<BOS>', 'it', "'s", 'become', 'like', 'a', 'boom', 'town', '.', '<EOS>'],
#  ['<BOS>',
#   'commander',
#   'of',
#   'base',
#   'sees',
#   'a',
#   'world',
#   'of',
#   'change',
#   '<EOS>'],
#  ['<BOS>',
#   'china',
#   'plays',
#   'down',
#   'friction',
#   'with',
#   'us',
#   'over',
#   'taiwan',
#   '<EOS>'],
#  ['<BOS>',
#   'that',
#   'translates',
#   'into',
#   'a',
#   '1',
#   'billionayear',
#   'business',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'this',
#   'is',
#   'a',
#   'crucial',
#   'presidential',
#   'election',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'but', 'he', 'wanted', 'to', 'sound', 'his', 'voice', '.', '<EOS>'],
#  ['<BOS>',
#   'venezuela',
#   "'s",
#   'chief',
#   'forced',
#   'to',
#   'resign',
#   'civilian',
#   'installed',
#   '<EOS>'],
#  ['<BOS>',
#   'japan',
#   ',',
#   'u.s.',
#   'differ',
#   'over',
#   'global',
#   'warming',
#   'issues',
#   '<EOS>'],
#  ['<BOS>',
#   'seven',
#   'marines',
#   'died',
#   'in',
#   'the',
#   'fiery',
#   'accident',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'government',
#   'urges',
#   'supporters',
#   'to',
#   'back',
#   'chavez',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'rumsfeld',
#   'defends',
#   'u.s.',
#   'treatment',
#   'of',
#   'detainees',
#   'in',
#   'cuba',
#   '<EOS>'],
#  ['<BOS>',
#   'mr.',
#   'bush',
#   "'s",
#   'approach',
#   'carries',
#   'considerable',
#   'risk',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'police',
#   'commissioner',
#   'augustine',
#   'chihuri',
#   'denied',
#   'the',
#   'reports',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'mugabe',
#   'wins',
#   'poll',
#   ',',
#   'amid',
#   'claims',
#   'of',
#   'rigging',
#   '<EOS>'],
#  ['<BOS>',
#   'venezuela',
#   'is',
#   'this',
#   'hemisphere',
#   "'s",
#   'secondoldest',
#   'democracy',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'halogen',
#   'lights',
#   'stay',
#   'on',
#   'all',
#   'night',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'fleet',
#   'hospital',
#   '20',
#   'has',
#   'nine',
#   'patients',
#   'today',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'detainees',
#   'also',
#   'get',
#   'fingerprinted',
#   'and',
#   'photographed',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'they',
#   'look',
#   'like',
#   'giant',
#   'bright',
#   'orange',
#   'flies',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'not', 'at', 'the', 'hands', 'of', 'the', 'guards', '.', '<EOS>'],
#  ['<BOS>', 'i', 'wish', 'i', 'had', 'more', 'time', '.', "''", '<EOS>'],
#  ['<BOS>',
#   'britain',
#   "'s",
#   'prescott',
#   'pushes',
#   'for',
#   'kyoto',
#   'pact',
#   'backing',
#   '<EOS>'],
#  ['<BOS>',
#   'other',
#   'administrations',
#   'have',
#   'talked',
#   'about',
#   'these',
#   'issues',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'there',
#   'are',
#   'things',
#   'i',
#   'would',
#   'point',
#   'to',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'q', 'at', 'what', 'levels', 'are', 'we', 'talking', '?', '<EOS>'],
#  ['<BOS>',
#   'u.s.',
#   'wants',
#   'kyoto',
#   'dropped',
#   'from',
#   'u.n.',
#   'meet',
#   'agenda',
#   '<EOS>'],
#  ['<BOS>', 'the', 'us', 'report', 'came', 'out', 'last', 'week', '.', '<EOS>'],
#  ['<BOS>', 'quite', 'a', 'lot', ',', 'as', 'it', 'happens', '.', '<EOS>'],
#  ['<BOS>',
#   'mugabe',
#   'confident',
#   'of',
#   'victory',
#   'in',
#   'historic',
#   'zimbabwe',
#   'vote',
#   '<EOS>'],
#  ['<BOS>',
#   'our',
#   'initial',
#   'reports',
#   'have',
#   'no',
#   'injuries',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'about',
#   '220',
#   'people',
#   'are',
#   'arriving',
#   'from',
#   'kyrgyzstan',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'he', 'was', 'as', 'good', 'as', 'his', 'word', '.', '<EOS>'],
#  ['<BOS>',
#   'there',
#   'were',
#   'no',
#   'immediate',
#   'reports',
#   'of',
#   'casualties',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'there',
#   'were',
#   '1,200',
#   'soldiers',
#   'aboard',
#   'the',
#   'ferry',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'it',
#   'is',
#   'also',
#   'the',
#   'biggest',
#   'terrorist',
#   'country',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'the',
#   'political',
#   'warning',
#   'must',
#   'be',
#   'heeded',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'its', 'total', 'weight', 'was', 'about', '1', 'kg', '.', '<EOS>'],
#  ['<BOS>',
#   'that',
#   'was',
#   'with',
#   'the',
#   'us',
#   'atlantis',
#   'shuttle',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'czech',
#   'republic',
#   'suspicious',
#   'consignment',
#   'appears',
#   'in',
#   'karlovy',
#   'vary',
#   '<EOS>'],
#  ['<BOS>',
#   'this',
#   'is',
#   'truly',
#   'a',
#   'very',
#   'despicable',
#   'act',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'this',
#   'maybe',
#   'a',
#   'surprise',
#   'to',
#   'many',
#   'people',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'it',
#   'will',
#   'be',
#   'disastrous',
#   'to',
#   'many',
#   'countries',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'a',
#   'roundtable',
#   'discussion',
#   'will',
#   'also',
#   'take',
#   'place',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'for',
#   'example',
#   ',',
#   'a',
#   'new',
#   'israeliarab',
#   'war',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'the', 'world', 'has', 'heated', 'up', 'a', 'notch', '.', '<EOS>'],
#  ['<BOS>',
#   'france',
#   "'s",
#   'chirac',
#   'talks',
#   'to',
#   'pakistan',
#   "'s",
#   'musharraf',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'president',
#   'george',
#   'w.',
#   'bush',
#   'determined',
#   'otherwise',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'the',
#   'world',
#   'is',
#   'a',
#   'perverse',
#   'place',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'america', 'can', 'not', 'do', 'it', 'so', 'far', '.', '<EOS>'],
#  ['<BOS>',
#   'mao',
#   'tsetung',
#   'was',
#   'passionate',
#   'about',
#   'this',
#   'idea',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'khatami',
#   'congratulates',
#   'venezuelan',
#   'nation',
#   'for',
#   'chavez',
#   "'",
#   'return',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'ousted',
#   'president',
#   'was',
#   'freed',
#   'by',
#   'paratroopers',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'specialist',
#   'rivas',
#   'said',
#   'he',
#   'ignored',
#   'the',
#   'press',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'joyous',
#   'south',
#   'african',
#   'enjoying',
#   'view',
#   'on',
#   'space',
#   'station',
#   '<EOS>'],
#  ['<BOS>',
#   'well',
#   ',',
#   'heaven',
#   'without',
#   'the',
#   '72',
#   'virgins',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'so',
#   'make',
#   'that',
#   '"',
#   'necessary',
#   'restraint',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'his',
#   'boss',
#   'apparently',
#   'has',
#   'less',
#   'business',
#   'sense',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'president',
#   'unleashes',
#   'army',
#   ',',
#   'rocket',
#   'launchers',
#   ',',
#   'mig21s',
#   '<EOS>'],
#  ['<BOS>', 'this', 'is', 'not', 'a', 'price', 'worth', 'paying', '.', '<EOS>'],
#  ['<BOS>',
#   'canada',
#   'to',
#   'hand',
#   'any',
#   'war',
#   'captives',
#   'to',
#   'u.s.',
#   '<EOS>'],
#  ['<BOS>',
#   'in',
#   'praise',
#   'of',
#   'those',
#   "'",
#   'damn',
#   'yankees',
#   "'",
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'confusion',
#   'was',
#   'widespread',
#   'throughout',
#   'his',
#   'party',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'only',
#   'special',
#   'military',
#   'commissions',
#   'can',
#   'try',
#   'them',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'this',
#   'enormous',
#   'difference',
#   'is',
#   'not',
#   'enough',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'fogh',
#   'they',
#   'must',
#   'be',
#   'given',
#   'a',
#   'fair',
#   'trial',
#   '<EOS>'],
#  ['<BOS>',
#   'no',
#   'one',
#   'was',
#   'arrested',
#   ',',
#   'police',
#   'said',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'us', 'bases', 'out', 'now', 'from', 'okinawa', '.', '"', '<EOS>'],
#  ['<BOS>',
#   'we',
#   'are',
#   'not',
#   'going',
#   'to',
#   'remain',
#   'silent',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'america',
#   'has',
#   'a',
#   'double',
#   'standard',
#   'policy',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'symptoms',
#   'appeared',
#   'within',
#   'a',
#   'few',
#   'days',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'this',
#   'time',
#   'washington',
#   'is',
#   'largely',
#   'keeping',
#   'silent',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'resolution',
#   'forced',
#   'him',
#   'into',
#   'a',
#   'corner',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'this',
#   'is',
#   'a',
#   'conflict',
#   'without',
#   'winners',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'it', 'is', 'heresy', ',', '"', 'said', 'cao', '.', '<EOS>'],
#  ['<BOS>',
#   'without',
#   'a',
#   'trial',
#   ',',
#   'without',
#   'an',
#   'attorney',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'some',
#   'terminological',
#   'refinements',
#   'came',
#   'up',
#   'as',
#   'well',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'navy',
#   "'s",
#   'problems',
#   'are',
#   'very',
#   'large',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'stable',
#   'ocean',
#   'traffic',
#   'is',
#   'an',
#   'absolute',
#   'necessity',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'so',
#   'this',
#   'new',
#   'version',
#   'has',
#   'new',
#   'bases',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'environmentalists',
#   'immediately',
#   'attacked',
#   'this',
#   'us',
#   'proposal',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'environmentalists',
#   'immediately',
#   'attacked',
#   'this',
#   'us',
#   'proposal',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'demand',
#   'for',
#   'these',
#   'technologies',
#   'is',
#   'increasing',
#   'worldwide',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'kono',
#   'issues',
#   'his',
#   'email',
#   'magazine',
#   'almost',
#   'daily',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'there',
#   'are',
#   'watchtowers',
#   'at',
#   'its',
#   'four',
#   'corners',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'use',
#   'of',
#   'tobacco',
#   'shall',
#   'be',
#   'permitted',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'pows',
#   'shall',
#   'have',
#   'the',
#   'opportunity',
#   'to',
#   'exercise',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'this', 'is', 'the', 'crux', 'of', 'the', 'issue', '.', '<EOS>'],
#  ['<BOS>',
#   'one',
#   'military',
#   'tribunal',
#   'will',
#   'try',
#   'these',
#   'prisoners',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'entire',
#   'camp',
#   'is',
#   'surrounded',
#   'by',
#   'fences',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'problem',
#   'is',
#   'neither',
#   'simple',
#   'nor',
#   'minor',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'the',
#   'federal',
#   'police',
#   'cleared',
#   'the',
#   'area',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'atmosphere',
#   'heats',
#   'up',
#   'in',
#   'financial',
#   'district',
#   'exchange',
#   'offices',
#   '<EOS>'],
#  ['<BOS>',
#   'weak',
#   'dollar',
#   'sends',
#   'merval',
#   'index',
#   'down',
#   '10.68',
#   'percent',
#   '<EOS>'],
#  ['<BOS>',
#   'one',
#   'of',
#   'the',
#   'rescued',
#   'sailors',
#   'died',
#   'later',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'we',
#   'have',
#   'to',
#   'keep',
#   'them',
#   'happy',
#   'and',
#   'healthy',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'craner',
#   'well',
#   ',',
#   'i',
#   'would',
#   'say',
#   'two',
#   'things',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'there',
#   'has',
#   'been',
#   'no',
#   'criticism',
#   'of',
#   'the',
#   'count',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'midweek',
#   'wheel',
#   'turns',
#   'with',
#   'a',
#   'vengeance',
#   'for',
#   'the',
#   'taliban',
#   '<EOS>'],
#  ['<BOS>',
#   'mdc',
#   'leader',
#   'tsvangirai',
#   'at',
#   'it',
#   'again',
#   'in',
#   'south',
#   'africa',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'situation',
#   'has',
#   'escalated',
#   'wildly',
#   'since',
#   'the',
#   'election',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'there',
#   'is',
#   'no',
#   'case',
#   'to',
#   'answer',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'a',
#   'soldier',
#   'sustained',
#   'injuries',
#   'in',
#   'the',
#   'shoot',
#   'out',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'what',
#   'will',
#   'i',
#   'be',
#   'wanting',
#   'in',
#   'europe',
#   '?',
#   '<EOS>'],
#  ['<BOS>',
#   'sharon',
#   'has',
#   'not',
#   'brought',
#   'the',
#   'israeli',
#   'public',
#   'security',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'total',
#   'amount',
#   'paid',
#   'out',
#   'was',
#   'hr112.7',
#   'million',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'it',
#   'delivered',
#   'that',
#   'blow',
#   ',',
#   'and',
#   'hit',
#   'argentina',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'i',
#   'await',
#   'the',
#   'british',
#   'officials',
#   "'",
#   'report',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'it',
#   'violates',
#   'the',
#   'rule',
#   'of',
#   'law',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'an',
#   'independent',
#   'electoral',
#   'commission',
#   'appoints',
#   'professional',
#   'election',
#   'officials',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'two',
#   'pm',
#   'pistols',
#   'were',
#   'found',
#   'at',
#   'the',
#   'site',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'he',
#   'was',
#   'detained',
#   'in',
#   'march',
#   '2002',
#   'once',
#   'again',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'all',
#   'these',
#   'are',
#   'eyesores',
#   'to',
#   'the',
#   'united',
#   'states',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'this',
#   'was',
#   'the',
#   'third',
#   'failure',
#   'in',
#   'a',
#   'row',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'he',
#   'leaves',
#   'behind',
#   'a',
#   'wife',
#   'and',
#   'four',
#   'children',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'circulation',
#   'of',
#   'the',
#   '18page',
#   'document',
#   'will',
#   'begin',
#   'today',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'soldiers',
#   'will',
#   'never',
#   'point',
#   'their',
#   'weapons',
#   'at',
#   'unarmed',
#   'people',
#   '<EOS>'],
#  ['<BOS>',
#   'these',
#   'incidents',
#   'generally',
#   'increase',
#   'in',
#   'spring',
#   'and',
#   'fall',
#   '.',
#   '<EOS>'],
#  ['<BOS>', '"', 'just', 'avoid', 'that', 'one', 'for', 'now', '.', '<EOS>'],
#  ['<BOS>',
#   'the',
#   'news',
#   'from',
#   'israel',
#   'is',
#   'almost',
#   'earthshattering',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'around',
#   '4.5',
#   'percent',
#   'growth',
#   'was',
#   'caught',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'israel',
#   'has',
#   'never',
#   'abandoned',
#   'its',
#   'aggressive',
#   'ambitions',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'trying',
#   'to',
#   'destroy',
#   'it',
#   'now',
#   'is',
#   'inconsistent',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'externally',
#   ',',
#   'sinous',
#   'relations',
#   'are',
#   'increasingly',
#   'improving',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'taiwan',
#   'is',
#   'an',
#   'inseparable',
#   'part',
#   'of',
#   'china',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'that', ',', 'however', ',', 'is', 'the', 'problem', '.', '<EOS>'],
#  ['<BOS>',
#   'the',
#   'european',
#   'commission',
#   'strongly',
#   'welcomes',
#   'this',
#   'decision',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'without',
#   'kyoto',
#   ',',
#   'the',
#   'figure',
#   'would',
#   'be',
#   '34',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'yet',
#   'rising',
#   'temperatures',
#   'pose',
#   'little',
#   'threat',
#   'to',
#   'canada',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '...',
#   'for',
#   'once',
#   ',',
#   'canada',
#   'needs',
#   'to',
#   'lead',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'peronist',
#   'to',
#   'head',
#   'argentina',
#   'at',
#   'least',
#   'till',
#   'march',
#   'elections',
#   '<EOS>'],
#  ['<BOS>',
#   'government',
#   'officials',
#   'declined',
#   'to',
#   'comment',
#   'on',
#   'the',
#   'deployment',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'guantanamo',
#   'has',
#   'detention',
#   'space',
#   'for',
#   'about',
#   '100',
#   'people',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'china',
#   'is',
#   'firmly',
#   'opposed',
#   'to',
#   'the',
#   'remarks',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'goldin',
#   "'s",
#   'was',
#   'to',
#   'cut',
#   'nasa',
#   "'s",
#   'budget',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'we',
#   'will',
#   'urge',
#   'there',
#   'be',
#   'no',
#   'provocation',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'why',
#   'not',
#   '?',
#   '"',
#   'snaps',
#   'the',
#   'reporter',
#   '.',
#   '<EOS>'],
#  ['<BOS>', '"', 'oh', 'god', 'no', ',', '"', 'he', 'says', '.', '<EOS>'],
#  ['<BOS>',
#   'buenos',
#   'aires',
#   ' ',
#   'nostalgia',
#   'runs',
#   'deep',
#   'in',
#   'argentina',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'that',
#   "'s",
#   'exactly',
#   'what',
#   'duhalde',
#   'most',
#   'lacks',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'he',
#   'promised',
#   'that',
#   'they',
#   'would',
#   'receive',
#   'government',
#   'benefits',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'our',
#   'enemies',
#   'rely',
#   'upon',
#   'surprise',
#   'and',
#   'deception',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'mr.',
#   'howard',
#   'was',
#   'chairman',
#   'of',
#   'the',
#   'threenation',
#   'committee',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'more',
#   'prisoners',
#   'detained',
#   'in',
#   'guantanamo',
#   'bay',
#   'join',
#   'hunger',
#   'strike',
#   '<EOS>'],
#  ['<BOS>',
#   'his',
#   'comments',
#   'came',
#   'as',
#   'criticism',
#   'swelled',
#   'from',
#   'abroad',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'there',
#   'is',
#   'no',
#   'explanation',
#   'for',
#   'the',
#   'delay',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'terms',
#   'of',
#   'the',
#   'aid',
#   'program',
#   'were',
#   'wrenching',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'argentina',
#   "'s",
#   'chaos',
#   'raises',
#   'new',
#   'doubts',
#   'on',
#   'monetary',
#   'fund',
#   '<EOS>'],
#  ['<BOS>',
#   'bush',
#   "'s",
#   'policy',
#   'on',
#   'argentina',
#   'signals',
#   'shift',
#   'in',
#   'approach',
#   '<EOS>'],
#  ['<BOS>',
#   'mugabe',
#   "'s",
#   'government',
#   'dismissed',
#   'criticism',
#   'of',
#   'the',
#   'election',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'it',
#   'means',
#   'he',
#   'ca',
#   "n't",
#   'look',
#   'ahead',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'now',
#   'they',
#   'do',
#   'pretty',
#   'much',
#   'as',
#   'directed',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'pressure',
#   'on',
#   'the',
#   'eye',
#   'had',
#   'become',
#   'unbearable',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'still',
#   ',',
#   'it',
#   'provides',
#   'a',
#   'bit',
#   'of',
#   'drama',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'u.s.',
#   'tells',
#   'china',
#   'taiwan',
#   'remarks',
#   'a',
#   'mistake',
#   ' ',
#   'xinhua',
#   '<EOS>'],
#  ['<BOS>',
#   'when',
#   'is',
#   'a',
#   'war',
#   'prisoner',
#   'not',
#   'a',
#   'pow',
#   '?',
#   '<EOS>'],
#  ['<BOS>',
#   'when',
#   'the',
#   'u.s.',
#   'brings',
#   'afghan',
#   'detainees',
#   'to',
#   'guantanamo',
#   'bay',
#   '<EOS>'],
#  ['<BOS>',
#   'sometimes',
#   'he',
#   'laughs',
#   'uncomfortably',
#   'when',
#   'questioned',
#   'by',
#   'journalists',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'terrorist',
#   'thugs',
#   'at',
#   'gitmo',
#   'do',
#   "n't",
#   'deserve',
#   'their',
#   'treatment',
#   '<EOS>'],
#  ['<BOS>',
#   'powell',
#   'said',
#   'chavez',
#   'was',
#   'aware',
#   'of',
#   'the',
#   'complaints',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'television',
#   'commentaries',
#   'were',
#   'even',
#   'more',
#   'full',
#   'of',
#   'praise',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'good',
#   'and',
#   'evil',
#   'are',
#   'two',
#   'completely',
#   'contradictory',
#   'concepts',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'pakistan',
#   'has',
#   'pledged',
#   '100',
#   'million',
#   'for',
#   'afghan',
#   'reconstruction',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'association',
#   'annually',
#   'allocates',
#   'jd100,000',
#   'for',
#   'training',
#   'graduates',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'for',
#   'every',
#   'effect',
#   ',',
#   'there',
#   'is',
#   'a',
#   'cause',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'it',
#   'will',
#   'have',
#   'a',
#   'deleterious',
#   'effect',
#   'on',
#   'mankind',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'its',
#   'effort',
#   'is',
#   'well',
#   'recognized',
#   'around',
#   'the',
#   'globe',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'next',
#   'step',
#   'will',
#   'be',
#   'even',
#   'more',
#   'difficult',
#   '.',
#   '<EOS>'],
#  ['<BOS>', 'it', 'is', 'a', 'long', 'road', 'ahead', 'of', 'us', '.', '<EOS>'],
#  ['<BOS>',
#   'this',
#   'is',
#   'actually',
#   'one',
#   'of',
#   'the',
#   'deeprooted',
#   'facts',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'taliban',
#   'leaders',
#   '"',
#   'created',
#   'misery',
#   'for',
#   'our',
#   'people',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'difficult',
#   'for',
#   'britain',
#   'and',
#   'france',
#   'to',
#   'agree',
#   'with',
#   'us',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'mozambican',
#   'soldiers',
#   'have',
#   'promised',
#   'to',
#   'act',
#   'quickly',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'this',
#   'is',
#   'a',
#   'very',
#   'important',
#   'lesson',
#   'for',
#   'indonesia',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'under',
#   'these',
#   'circumstances',
#   'nobody',
#   'can',
#   'feel',
#   'free',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'fate',
#   'of',
#   "'",
#   'detainees',
#   "'",
#   'hangs',
#   'on',
#   'us',
#   'wording',
#   '<EOS>'],
#  ['<BOS>',
#   'rockthrowing',
#   'youths',
#   'responded',
#   'as',
#   'the',
#   'rally',
#   'wound',
#   'down',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'violent',
#   'protests',
#   'in',
#   'argentina',
#   'president',
#   'duhalde',
#   'calls',
#   'for',
#   'calm',
#   '<EOS>'],
#  ['<BOS>',
#   'cardoso',
#   'says',
#   'us',
#   'decision',
#   'on',
#   'greenhouse',
#   'gases',
#   'is',
#   'positive',
#   '<EOS>'],
#  ['<BOS>',
#   'america',
#   'is',
#   'axis',
#   'of',
#   'evil',
#   'for',
#   'the',
#   'arab',
#   'world',
#   '<EOS>'],
#  ['<BOS>',
#   'shuttle',
#   "'s",
#   'tanks',
#   'have',
#   'been',
#   'filled',
#   'with',
#   'fuel',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'hugo',
#   'chavez',
#   'managed',
#   'to',
#   'demonstrate',
#   'astonishing',
#   'political',
#   'resistance',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'africa',
#   'endorses',
#   'mugabe',
#   'victory',
#   ',',
#   'the',
#   'west',
#   'condemns',
#   'it',
#   '<EOS>'],
#  ['<BOS>',
#   'officers',
#   'raided',
#   'storehouses',
#   ',',
#   'seizing',
#   'dozens',
#   'of',
#   'firearms',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'others',
#   'stand',
#   'or',
#   'pace',
#   'around',
#   'before',
#   'slumping',
#   'again',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'come',
#   'to',
#   'pray',
#   ',',
#   'come',
#   'to',
#   'success',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>', '"', 'it', 'bothers', 'me', ',', '"', 'he', 'said', '.', '<EOS>'],
#  ['<BOS>',
#   'two',
#   'russians',
#   'are',
#   'also',
#   'among',
#   'the',
#   'sixmember',
#   'crew',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'at',
#   'the',
#   'moment',
#   'it',
#   "'s",
#   'a',
#   'challenge',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'people',
#   'are',
#   'willing',
#   'to',
#   'fight',
#   'it',
#   'out',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'there',
#   'are',
#   'better',
#   'ways',
#   'to',
#   'spend',
#   'that',
#   'money',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'i',
#   'have',
#   'been',
#   'to',
#   'tibet',
#   'many',
#   'times',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'matter',
#   'raises',
#   'major',
#   'questions',
#   'of',
#   'international',
#   'law',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   "'",
#   'gitmo',
#   "'",
#   'camp',
#   'is',
#   'many',
#   'things',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'suicide',
#   'attacks',
#   'do',
#   'not',
#   'require',
#   'an',
#   'extensive',
#   'infrastructure',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'no',
#   'one',
#   'wanted',
#   'to',
#   'argue',
#   'with',
#   'the',
#   'master',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'the',
#   'warming',
#   'will',
#   'definitely',
#   'not',
#   'be',
#   'uniform',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'obligations',
#   'of',
#   'foreign',
#   'countries',
#   'under',
#   'the',
#   'kyoto',
#   'protocol',
#   '<EOS>'],
#  ['<BOS>',
#   'it',
#   'provides',
#   'for',
#   'economic',
#   'mechanisms',
#   'of',
#   'international',
#   'cooperation',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'it',
#   'is',
#   'hard',
#   'to',
#   'disagree',
#   'with',
#   'this',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'kawamura',
#   'japan',
#   'and',
#   'taiwan',
#   'are',
#   'both',
#   'exporting',
#   'nations',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'question',
#   'where',
#   'is',
#   'china',
#   "'s",
#   'true',
#   'threat',
#   'to',
#   'taiwan',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'kyoto',
#   'protocol',
#   'is',
#   'a',
#   'first',
#   'major',
#   'step',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'united',
#   'states',
#   'is',
#   'one',
#   'of',
#   'the',
#   'signatories',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'prisoners',
#   "'",
#   'hands',
#   'and',
#   'feet',
#   'are',
#   'shackled',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'this',
#   'our',
#   'conscience',
#   'ought',
#   'not',
#   'to',
#   'permit',
#   'us',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'brazil',
#   'contributed',
#   'greatly',
#   'to',
#   'the',
#   'success',
#   'in',
#   'marrakesh',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'figure',
#   'show',
#   'the',
#   'hightech',
#   'crisis',
#   'is',
#   'continuing',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'saad',
#   'will',
#   'remain',
#   'in',
#   'custody',
#   'until',
#   'the',
#   'trial',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'navy',
#   'vessel',
#   'escaped',
#   'serious',
# ...
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'first',
#   'factor',
#   'deals',
#   'with',
#   'the',
#   'nation',
#   "'s",
#   'general',
#   'mood',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'coup',
#   'making',
#   'might',
#   'have',
#   'been',
#   'acceptable',
#   'during',
#   'the',
#   'cold',
#   'war',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'story',
#   'could',
#   'have',
#   'devastating',
#   'consequence',
#   'for',
#   'the',
#   'bush',
#   'administration',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'people',
#   'in',
#   'these',
#   'lines',
#   'were',
#   'in',
#   'a',
#   'foul',
#   'mood',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'in',
#   'addition',
#   ',',
#   'exporters',
#   'have',
#   'started',
#   'settling',
#   'their',
#   'pending',
#   'transactions',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'kenya',
#   '"',
#   'highly',
#   'contagious',
#   '"',
#   'type',
#   'of',
#   'tuberculosis',
#   'reported',
#   'in',
#   'embu',
#   '<EOS>'],
#  ['<BOS>',
#   'kasyanov',
#   'will',
#   'fly',
#   'to',
#   'hanoi',
#   'from',
#   'ulanbator',
#   'on',
#   'march',
#   '26',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'carrier',
#   'rocket',
#   'is',
#   'the',
#   'foundation',
#   'of',
#   'space',
#   'exploration',
#   'and',
#   'utilization',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'a',
#   'japanese',
#   'made',
#   'h2a',
#   'rocket',
#   'will',
#   'launch',
#   'this',
#   'satellite',
#   'in',
#   '2002',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'japan',
#   'previously',
#   'developed',
#   'the',
#   'l',
#   'and',
#   'm',
#   'series',
#   'of',
#   'launch',
#   'vehicles',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'it',
#   'is',
#   'also',
#   'the',
#   'path',
#   'to',
#   'becoming',
#   'a',
#   'major',
#   'military',
#   'power',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'outstanding',
#   'among',
#   'these',
#   'are',
#   ' ',
#   'the',
#   'fan',
#   'is',
#   'apolitical',
#   'and',
#   'nondeliberating',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'this',
#   'is',
#   'to',
#   'generate',
#   '"',
#   'antagonism',
#   '"',
#   'within',
#   'the',
#   'public',
#   'opinion',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'turkish',
#   'citizens',
#   'from',
#   'southern',
#   'and',
#   'southeastern',
#   'provinces',
#   'accounted',
#   'for',
#   '31',
#   'percent',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'we',
#   'have',
#   'all',
#   'the',
#   'equipment',
#   'required',
#   ',',
#   '"',
#   'he',
#   'said',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'lg',
#   'also',
#   'plans',
#   'to',
#   'upgrade',
#   'the',
#   'current',
#   'system',
#   'beginning',
#   '2002',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'he',
#   'has',
#   'been',
#   'taken',
#   'to',
#   'a',
#   'jail',
#   'close',
#   'to',
#   'washington',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'base',
#   'in',
#   'guantanamo',
#   'bay',
#   'was',
#   'chosen',
#   'for',
#   'two',
#   'reasons',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'moscow',
#   'has',
#   'expressed',
#   'the',
#   'wish',
#   'to',
#   'import',
#   'more',
#   'mongolian',
#   'meat',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'people',
#   'have',
#   'seen',
#   'the',
#   'true',
#   'features',
#   'of',
#   'these',
#   'space',
#   'capsules',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'team',
#   'is',
#   'to',
#   'return',
#   'to',
#   'earth',
#   'on',
#   'may',
#   '5',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'shuttleworth',
#   'agreed',
#   'that',
#   'this',
#   'was',
#   'essential',
#   'towards',
#   'africa',
#   "'s",
#   'rebirth',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'military',
#   'threat',
#   'persists',
#   'after',
#   'events',
#   'in',
#   'venezuela',
#   ',',
#   'spanish',
#   'daily',
#   'says',
#   '<EOS>'],
#  ['<BOS>',
#   'turkey',
#   'and',
#   'greece',
#   'have',
#   'the',
#   'opportunity',
#   'of',
#   'cooperating',
#   'in',
#   'tourism',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'state',
#   'minister',
#   'dervis',
#   'will',
#   'deliver',
#   'a',
#   'speech',
#   'at',
#   'the',
#   'conference',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'desperate',
#   'fight',
#   'even',
#   'took',
#   'tolls',
#   'of',
#   'women',
#   'and',
#   'children',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'as',
#   'a',
#   'result',
#   ',',
#   'the',
#   'situation',
#   'has',
#   'become',
#   'tense',
#   'again',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'president',
#   'bush',
#   'is',
#   'facing',
#   'a',
#   'recession',
#   'and',
#   'an',
#   'economic',
#   'crisis',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'this',
#   'system',
#   'of',
#   'freedoms',
#   'made',
#   'him',
#   'president',
#   'of',
#   'the',
#   'republic',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'they',
#   'will',
#   'not',
#   'be',
#   'determined',
#   'to',
#   'be',
#   'pows',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'friday',
#   "'s",
#   'attack',
#   'strikes',
#   'at',
#   'the',
#   'heart',
#   'of',
#   'this',
#   'authority',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'scientific',
#   'evidence',
#   'on',
#   'climate',
#   'change',
#   'is',
#   'stronger',
#   'than',
#   'ever',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'to',
#   'protect',
#   'our',
#   'climate',
#   'we',
#   'will',
#   'have',
#   'to',
#   'reduce',
#   'emissions',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'appeal',
#   'is',
#   'not',
#   'possible',
#   ',',
#   'but',
#   'the',
#   'death',
#   'penalty',
#   'is',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'it',
#   'is',
#   'another',
#   'matter',
#   'to',
#   'launch',
#   'into',
#   'scandal',
#   'or',
#   'antiamericanism',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'spanish',
#   'daily',
#   'urges',
#   'caution',
#   'in',
#   'judging',
#   'usa',
#   "'s",
#   'treatment',
#   'of',
#   'suspects',
#   '<EOS>'],
#  ['<BOS>',
#   'france',
#   'says',
#   'time',
#   'is',
#   'right',
#   'for',
#   'joint',
#   'useuropean',
#   'action',
#   'on',
#   'mideast',
#   '<EOS>'],
#  ['<BOS>',
#   'this',
#   'is',
#   'a',
#   'breach',
#   'of',
#   'the',
#   'very',
#   'constitution',
#   'of',
#   'wto',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'wto',
#   'claims',
#   'that',
#   'it',
#   'wants',
#   'to',
#   'protect',
#   'the',
#   'environment',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'they',
#   'walk',
#   ',',
#   'they',
#   'shut',
#   'up',
#   ',',
#   'they',
#   'lower',
#   'their',
#   'heads',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'it',
#   'must',
#   'be',
#   'freaky',
#   ',',
#   '"',
#   'chimes',
#   'in',
#   'her',
#   'colleague',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'finally',
#   ',',
#   'an',
#   'interpreter',
#   'comes',
#   'in',
#   'to',
#   'talk',
#   'to',
#   'the',
#   'patient',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'at',
#   'this',
#   'moment',
#   ',',
#   'i',
#   'do',
#   "n't",
#   'have',
#   'an',
#   'answer',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'morning',
#   'run',
#   'to',
#   'fleet',
#   'hospital',
#   '20',
#   'takes',
#   'place',
#   'as',
#   'scheduled',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'a',
#   'german',
#   'shepherd',
#   'and',
#   'his',
#   'handler',
#   'patrol',
#   'the',
#   'camp',
#   "'s",
#   'perimeter',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'base',
#   'officials',
#   'say',
#   'there',
#   'are',
#   'christian',
#   'prisoners',
#   'as',
#   'well',
#   'as',
#   'muslims',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'bush',
#   'takes',
#   'great',
#   'leap',
#   'forward',
#   'in',
#   'pledging',
#   'u.s.',
#   'help',
#   'in',
#   'defending',
#   'taiwan',
#   '<EOS>'],
#  ['<BOS>',
#   'i',
#   "'ll",
#   'make',
#   'sure',
#   'that',
#   'he',
#   'does',
#   "n't",
#   'have',
#   'it',
#   '.',
#   "''",
#   '<EOS>'],
#  ['<BOS>',
#   'we',
#   'buy',
#   'our',
#   'own',
#   'snacks',
#   'and',
#   'do',
#   'our',
#   'own',
#   'laundry',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'my',
#   'buddy',
#   ',',
#   'a',
#   'connecticut',
#   'cop',
#   ',',
#   'finds',
#   'the',
#   'protests',
#   'fascinating',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'on',
#   'this',
#   'count',
#   ',',
#   'the',
#   'national',
#   'security',
#   'adviser',
#   'may',
#   'have',
#   'erred',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'q',
#   'is',
#   'that',
#   'something',
#   'we',
#   "'ve",
#   'talked',
#   'to',
#   'the',
#   'saudis',
#   'about',
#   '?',
#   '<EOS>'],
#  ['<BOS>',
#   'number',
#   'one',
#   ',',
#   'i',
#   'disagree',
#   'that',
#   'it',
#   "'s",
#   'the',
#   'worst',
#   'violator',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'this',
#   'is',
#   'unacceptable',
#   'and',
#   'a',
#   'gross',
#   'misstatement',
#   'of',
#   'the',
#   'facts',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'it',
#   'was',
#   'won',
#   'on',
#   'the',
#   'issue',
#   'of',
#   'the',
#   'land',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'there',
#   'were',
#   '20',
#   '"',
#   'on',
#   'the',
#   'plane',
#   ',',
#   'lowell',
#   'said',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'it',
#   'did',
#   'not',
#   'perform',
#   'any',
#   'evasive',
#   'maneuvers',
#   ',',
#   '"',
#   'lowell',
#   'said',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'that',
#   'according',
#   'to',
#   'the',
#   'state',
#   'constituted',
#   'a',
#   'breach',
#   'of',
#   'the',
#   'loma',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'its',
#   'success',
#   'established',
#   'the',
#   'reputation',
#   'of',
#   'buenos',
#   'aires',
#   'on',
#   'international',
#   'markets',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'however',
#   ',',
#   'there',
#   'are',
#   'two',
#   'facts',
#   'that',
#   'ought',
#   'to',
#   'be',
#   'highlighted',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'we',
#   'believe',
#   'in',
#   'the',
#   'peaceful',
#   'settlement',
#   'of',
#   'this',
#   'issue',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'ild',
#   'network',
#   'is',
#   'based',
#   'on',
#   'ip',
#   'internet',
#   'protocol',
#   'centric',
#   'backbone',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'sharon',
#   'says',
#   'flatly',
#   'he',
#   'will',
#   'not',
#   'withdraw',
#   'from',
#   'a',
#   'single',
#   'settlement',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'another',
#   'enzyme',
#   'then',
#   'cuts',
#   'the',
#   'section',
#   'and',
#   'reveals',
#   'the',
#   'next',
#   'sequence',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'foreigners',
#   'will',
#   'be',
#   'deported',
#   'once',
#   'the',
#   'legal',
#   'proceedings',
#   'are',
#   'completed',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'average',
#   'daily',
#   'unloading',
#   'of',
#   'freight',
#   'cars',
#   'increased',
#   'overall',
#   'by',
#   '4.1',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'she',
#   'added',
#   'that',
#   'the',
#   'argentine',
#   'government',
#   'has',
#   'declared',
#   'a',
#   '30day',
#   'emergency',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'there',
#   'is',
#   'no',
#   'possibility',
#   'of',
#   'legally',
#   'selling',
#   'the',
#   'nuclear',
#   'waste',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'in',
#   'other',
#   'countries',
#   ',',
#   'there',
#   'is',
#   'no',
#   'scope',
#   'for',
#   'such',
#   'madness',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'same',
#   'situation',
#   'arises',
#   'if',
#   'the',
#   'president',
#   'dies',
#   'while',
#   'in',
#   'office',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'it',
#   'proposes',
#   'to',
#   'construct',
#   'a',
#   'gigantic',
#   'solar',
#   'power',
#   'plant',
#   'in',
#   'space',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'for',
#   'iran',
#   ',',
#   'bush',
#   "'s",
#   'condemnation',
#   'marked',
#   'a',
#   'return',
#   'to',
#   'confrontation',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'all',
#   'was',
#   'not',
#   'lost',
#   'in',
#   'zimbabwe',
#   "'s",
#   'rigged',
#   'election',
#   'last',
#   'week',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'such',
#   'desperation',
#   'by',
#   'mugabe',
#   'should',
#   'not',
#   'be',
#   'condoned',
#   'by',
#   'african',
#   'leaders',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'after',
#   'casting',
#   'his',
#   'ballot',
#   ',',
#   'mugabe',
#   'lashed',
#   'out',
#   'at',
#   'his',
#   'critics',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'china',
#   'disapproves',
#   'use',
#   'of',
#   "'",
#   'axis',
#   'of',
#   'evil',
#   "'",
#   'in',
#   'international',
#   'relations',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'mdc',
#   'leadership',
#   'was',
#   'to',
#   'meet',
#   'midmorning',
#   'to',
#   'discuss',
#   'the',
#   'results',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'company',
#   "'s",
#   'executives',
#   'revolted',
#   ',',
#   'threatening',
#   'a',
#   'cutoff',
#   'of',
#   'oil',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'he',
#   'has',
#   'sometimes',
#   'talked',
#   'of',
#   'remaining',
#   'president',
#   'past',
#   'the',
#   'year',
#   '2020',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'on',
#   'one',
#   'end',
#   ',',
#   'koizumi',
#   'defensively',
#   'holds',
#   'up',
#   'the',
#   'kyoto',
#   'protocol',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'as',
#   'we',
#   'sit',
#   'watching',
#   'cnn',
#   ',',
#   'an',
#   'unfounded',
#   'rumor',
#   'gains',
#   'currency',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'on',
#   'sunday',
#   ',',
#   'rumsfeld',
#   'visits',
#   ',',
#   'and',
#   'we',
#   'hope',
#   'for',
#   'illumination',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'i',
#   "'m",
#   'running',
#   'my',
#   'ass',
#   'off',
#   'chasing',
#   'you',
#   'guys',
#   'around',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'i',
#   "'m",
#   'not',
#   'sure',
#   ',',
#   '"',
#   'he',
#   'says',
#   ',',
#   'puzzled',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'it',
#   "'s",
#   'understandable',
#   'if',
#   'public',
#   'affairs',
#   'types',
#   'are',
#   'a',
#   'little',
#   'testy',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'you',
#   "'re",
#   'not',
#   'allowed',
#   'to',
#   'stay',
#   ',',
#   '"',
#   'says',
#   'costello',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'this',
#   'is',
#   'not',
#   'a',
#   'fair',
#   'election',
#   ',',
#   '"',
#   'he',
#   'says',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'in',
#   'rural',
#   'areas',
#   ',',
#   'many',
#   'polling',
#   'stations',
#   'stood',
#   'empty',
#   'by',
#   'midday',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'he',
#   'was',
#   'not',
#   'sure',
#   'the',
#   'kyoto',
#   'protocol',
#   'actually',
#   'went',
#   'far',
#   'enough',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'but',
#   'now',
#   'a',
#   'different',
#   'variety',
#   'of',
#   'nostalgia',
#   'appears',
#   'to',
#   'be',
#   'emerging',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'mr.',
#   'chavez',
#   'had',
#   'renamed',
#   'the',
#   'country',
#   'the',
#   'bolivarian',
#   'republic',
#   'of',
#   'venezuela',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'chavez',
#   'was',
#   'right',
#   'about',
#   'the',
#   'problems',
#   'he',
#   'saw',
#   'in',
#   'venezuela',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'president',
#   'fidel',
#   'castro',
#   'and',
#   'mr.',
#   'chavez',
#   'had',
#   'formed',
#   'a',
#   'close',
#   'friendship',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'diplomatic',
#   'relations',
#   'between',
#   'the',
#   'two',
#   'countries',
#   ',',
#   'however',
#   ',',
#   'would',
#   'continue',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'such',
#   'a',
#   'provocative',
#   'move',
#   'will',
#   'obviously',
#   'overshadow',
#   'the',
#   'renewed',
#   'sinous',
#   'relations',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'both',
#   'the',
#   'economy',
#   'and',
#   'the',
#   'environment',
#   'can',
#   'be',
#   'improved',
#   'together',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'at',
#   'least',
#   '15',
#   'people',
#   'are',
#   'killed',
#   'and',
#   'almost',
#   '100',
#   'are',
#   'wounded',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   ' ',
#   'carmona',
#   'takes',
#   'refuge',
#   'at',
#   'tiuna',
#   'fort',
#   ',',
#   'southwest',
#   'of',
#   'caracas',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'i',
#   'had',
#   'also',
#   'some',
#   'personal',
#   'things',
#   'to',
#   'deal',
#   'with',
#   '.',
#   '"',
#   '<EOS>'],
#  ['<BOS>',
#   'mr.',
#   'bush',
#   'promised',
#   'just',
#   'such',
#   'a',
#   'policy',
#   'during',
#   'his',
#   'presidential',
#   'campaign',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'zimbabwe',
#   'should',
#   'be',
#   'an',
#   'economic',
#   'beacon',
#   ',',
#   'not',
#   'a',
#   'basket',
#   'case',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'in',
#   'the',
#   'recovery',
#   'room',
#   ',',
#   'the',
#   'patient',
#   "'s",
#   'body',
#   'starts',
#   'trembling',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'two',
#   'boys',
#   'in',
#   'white',
#   'karate',
#   'outfits',
#   'run',
#   'down',
#   'palmlined',
#   'sherman',
#   'avenue',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'united',
#   'states',
#   'can',
#   'never',
#   'dampen',
#   'or',
#   'bend',
#   'our',
#   'unwavering',
#   'will',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'mankind',
#   'should',
#   'continue',
#   'to',
#   'work',
#   'on',
#   'a',
#   'solution',
#   'to',
#   'global',
#   'warming',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'deeper',
#   'the',
#   'international',
#   'crisis',
#   ',',
#   'the',
#   'better',
#   'for',
#   'george',
#   'bush',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'people',
#   'are',
#   'being',
#   'killed',
#   'in',
#   'masses',
#   'and',
#   'buried',
#   'in',
#   'collective',
#   'graves',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   '"',
#   'it',
#   'was',
#   'a',
#   'minor',
#   'clash',
#   ',',
#   'but',
#   'investigations',
#   'are',
#   'continuing',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'new',
#   'us',
#   'policy',
#   'deserves',
#   'to',
#   'be',
#   'closely',
#   'analyzed',
#   'and',
#   'monitored',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'the',
#   'circumstance',
#   'has',
#   'led',
#   'bush',
#   'to',
#   'again',
#   'adopt',
#   'an',
#   'aggressive',
#   'policy',
#   '.',
#   '<EOS>'],
#  ['<BOS>',
#   'durban',
#   'march',
#   '19',
#   'sapa',
#   'sa',
#   'observer',
#   'zim',
#   'elections',
#   'not',
#   'free',
#   'and',
#   'fair',
#   '<EOS>'],
#  ...]

# %%
print(len(words))
# Out:
# 8244

# %%
## average word length
sum([len(a) for a in words])/len(words)

# %%
trained_model.keys()
# Out:
# dict_keys(['train_weights', 'best_valid_accuracy', 'epoch', 'vocab', 'labels', 'optimizer', 'accuracies', 'state_dict', 'test_weights'])

# %%
hiddens = trained_model['train_weights']['hidden']
print(hiddens.shape)
# Out:
# torch.Size([8244, 300])

# %%
linear_reducer = PCA()
linear_reducer.fit(hiddens)
linear_reducer.explained_variance_ratio_[:5]
# Out:
# array([ 0.64190219,  0.05555807,  0.04960111,  0.03438417,  0.02937376])

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

scores = []
best_score = -1
best_clusters = None
best_k = None
for k in range(2, 50):
    km = KMeans(n_clusters = k)
    X = km.fit_predict(hiddens)
    score = silhouette_score(hiddens, X)
    scores.append(score)
    if score > best_score:
        best_clusters = X
        best_score = score
        best_k = k
        
print(best_score)
# Out:
# 0.490198

# %%
print(best_k)
print(scores)

# %%
len(best_clusters)
# Out:
# 8244

# %%
len(trained_model['train_weights']['targets'])
# Out:
# 8244

# %%
sum(best_clusters == trained_model['train_weights']['targets'])
# Out:
# 7788

# %%
(trained_model['train_weights']['preds'].nonzero())
# Out:
#     0
#     2
#     3
#   ⋮
#  8192
#  8203
#  8218
# [torch.LongTensor of size 2933x1]

# %%
import plotly.plotly as py
import plotly.graph_objs as go


# Create random data with numpy
import numpy as np

N = 1000
random_x = np.random.randn(N)
random_y = np.random.randn(N)

# Create a trace
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers', 
    hovertext = 250 * ['a', 'b', 'c', 'd']
)

data = [trace]

# Plot and embed in ipython notebook!
py.iplot(data)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~siddsach/2.embed" height="525px" width="100%"></iframe>

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

perplexities = range(5, 55, 10)

reduced_data = {}

for p in perplexities:
    
    print('Training T-SNE on hidden states for perplexity:{}...'.format(p))
    reducer = TSNE(n_components = 2, perplexity = p)
    reduced_data[p] = reducer.fit_transform(hiddens)
# Out:
# Training T-SNE on hidden states for perplexity:5...
# Training T-SNE on hidden states for perplexity:15...
# Training T-SNE on hidden states for perplexity:25...
# Training T-SNE on hidden states for perplexity:35...
# Training T-SNE on hidden states for perplexity:45...

# %%
import plotly.plotly as py
import plotly.graph_objs as go


# Create random data with numpy
import numpy as np

N = 1000
random_x = np.random.randn(N)
random_y = np.random.randn(N)
random_x2 = np.random.randn(N)
random_y2 = np.random.randn(N)

# Create a trace
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
    hovertext = 250 * ['a', 'b', 'c', 'd'],
    hoverinfo = 'text',
    marker = go.Marker(
                size = 4,
                color = 'blue'
    ),
    name = 'subjective'
)
trace2 = go.Scatter(
    x = random_x2,
    y = random_y2,
    mode = 'markers',
    hovertext = 250 * ['a', 'b', 'c', 'd'],
    hoverinfo = 'text',
    marker = go.Marker(
                size = 4,
                color = 'red'
    ),
    name = 'objective'
)

layout = go.Layout(
    xaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    ),
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    )
)

data = [trace, trace2]

fig = go.Figure(data = data, layout = layout)

# Plot and embed in ipython notebook!
print(trace.help('hovertext'))
py.iplot(fig, filename = 'test')
# Out:
# Current path: []
# Current parent object_names: []
#
# With the current parents, 'hovertext' can be used as follows:
#
# Under ('figure', 'data', 'scatter'):
#
#     description: Sets hover text elements associated with each (x,y) pair. If a single
#         string, the same string appears over all the data points. If an array of
#         string, the items are mapped in order to the this trace's (x,y)
#         coordinates. To be seen, trace `hoverinfo` must contain a *text* flag.
#     editType: style
#     role: info
#
#
#
# None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~siddsach/18.embed" height="525px" width="100%"></iframe>

# %%
p = 5
d = reduced_data[p]
subjective_inds = trained_model['train_weights']['preds'].nonzero()
subjective_inds = subjective_inds
subjective_sents = np.squeeze(d[subjective_inds])
objective_inds = (trained_model['train_weights']['preds'] == 0).nonzero()
objective_inds = objective_inds
objective_sents = np.squeeze(d[objective_inds])

texts = [' '.join(l) for l in words]
subjective_texts = [text for i, text in enumerate(texts) if torch.sum(subjective_inds == i)]
objective_texts = [text for i, text in enumerate(texts) if torch.sum(objective_inds == i)]

print("SUBJECTIVE")
print(len(subjective_texts))
print(subjective_sents.shape)
print("OBJECTIVE")
print(len(objective_texts))
print(objective_sents.shape)
subjective = go.Scatter(
                x = subjective_sents[:, 0], 
                y = subjective_sents[:, 1], 
                mode = 'markers',
                text = subjective_texts,
                hoverinfo = text, 
                marker = go.Marker(
                            color = 'red', 
                            size = 4
                ),
                name = 'Subjective'
            )
objective = go.Scatter(
                x = objective_sents[:, 0], 
                y = objective_sents[:, 1], 
                mode = 'markers',
                text = objective_texts, 
                hoverinfo = text, 
                marker = go.Marker(
                            color = 'blue', 
                            size = 4
                ),
                name = 'Objective'
            )

data = [subjective, objective]

layout = go.Layout(
    title = "t-SNE for perplexity: {}".format(p),
    hovermode = 'closest',
    xaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    ),
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    )
)

fig = go.Figure(data = data, layout = layout)
print('here')

# Plot and embed in ipython notebook!
py.iplot(fig, filename = 'Subjectivity Representations')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-101703cd730f> in <module>()
#       1 p = 5
# ----> 2 d = reduced_data[p]
#       3 subjective_inds = trained_model['train_weights']['preds'].nonzero()
#       4 subjective_inds = subjective_inds
#       5 subjective_sents = np.squeeze(d[subjective_inds])
#
# KeyError: 5

# %%
p = 15
d = reduced_data[p]
subjective_inds = trained_model['train_weights']['preds'].nonzero()
subjective_inds = subjective_inds
subjective_sents = np.squeeze(d[subjective_inds])
objective_inds = (trained_model['train_weights']['preds'] == 0).nonzero()
objective_inds = objective_inds
objective_sents = np.squeeze(d[objective_inds])

texts = [' '.join(l) for l in words]
subjective_texts = [text for i, text in enumerate(texts) if torch.sum(subjective_inds == i)]
objective_texts = [text for i, text in enumerate(texts) if torch.sum(objective_inds == i)]

print("SUBJECTIVE")
print(len(subjective_texts))
print(subjective_sents.shape)
print("OBJECTIVE")
print(len(objective_texts))
print(objective_sents.shape)
subjective = go.Scatter(
                x = subjective_sents[:, 0], 
                y = subjective_sents[:, 1], 
                mode = 'markers',
                text = subjective_texts,
                hoverinfo = text, 
                marker = go.Marker(
                            color = 'red', 
                            size = 4
                ),
                name = 'Subjective'
            )
objective = go.Scatter(
                x = objective_sents[:, 0], 
                y = objective_sents[:, 1], 
                mode = 'markers',
                text = objective_texts, 
                hoverinfo = text, 
                marker = go.Marker(
                            color = 'blue', 
                            size = 4
                ),
                name = 'Objective'
            )

data = [subjective, objective]

layout = go.Layout(
    title = "t-SNE for perplexity: {}".format(p),
    hovermode = 'closest',
    xaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    ),
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    )
)

fig = go.Figure(data = data, layout = layout)
print('here')

# Plot and embed in ipython notebook!
py.iplot(fig, filename = 'Subjectivity Representations')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-99102215d71e> in <module>()
#       1 p = 35
# ----> 2 d = reduced_data[p]
#       3 subjective_inds = trained_model['train_weights']['preds'].nonzero()
#       4 subjective_inds = subjective_inds
#       5 subjective_sents = np.squeeze(d[subjective_inds])
#
# KeyError: 35

# %%
p = 25
d = reduced_data[p]
subjective_inds = trained_model['train_weights']['preds'].nonzero()
subjective_inds = subjective_inds
subjective_sents = np.squeeze(d[subjective_inds])
objective_inds = (trained_model['train_weights']['preds'] == 0).nonzero()
objective_inds = objective_inds
objective_sents = np.squeeze(d[objective_inds])

texts = [' '.join(l) for l in words]
subjective_texts = [text for i, text in enumerate(texts) if torch.sum(subjective_inds == i)]
objective_texts = [text for i, text in enumerate(texts) if torch.sum(objective_inds == i)]

print("SUBJECTIVE")
print(len(subjective_texts))
print(subjective_sents.shape)
print("OBJECTIVE")
print(len(objective_texts))
print(objective_sents.shape)
subjective = go.Scatter(
                x = subjective_sents[:, 0], 
                y = subjective_sents[:, 1], 
                mode = 'markers',
                text = subjective_texts,
                hoverinfo = text, 
                marker = go.Marker(
                            color = 'red', 
                            size = 4
                ),
                name = 'Subjective'
            )
objective = go.Scatter(
                x = objective_sents[:, 0], 
                y = objective_sents[:, 1], 
                mode = 'markers',
                text = objective_texts, 
                hoverinfo = text, 
                marker = go.Marker(
                            color = 'blue', 
                            size = 4
                ),
                name = 'Objective'
            )

data = [subjective, objective]

layout = go.Layout(
    title = "t-SNE for perplexity: {}".format(p),
    hovermode = 'closest',
    xaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    ),
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    )
)

fig = go.Figure(data = data, layout = layout)
print('here')

# Plot and embed in ipython notebook!
py.iplot(fig, filename = 'Subjectivity Representations')

# %%
p = 35
d = reduced_data[p]
subjective_inds = trained_model['train_weights']['preds'].nonzero()
subjective_inds = subjective_inds
subjective_sents = np.squeeze(d[subjective_inds])
objective_inds = (trained_model['train_weights']['preds'] == 0).nonzero()
objective_inds = objective_inds
objective_sents = np.squeeze(d[objective_inds])

texts = [' '.join(l) for l in words]
subjective_texts = [text for i, text in enumerate(texts) if torch.sum(subjective_inds == i)]
objective_texts = [text for i, text in enumerate(texts) if torch.sum(objective_inds == i)]

print("SUBJECTIVE")
print(len(subjective_texts))
print(subjective_sents.shape)
print("OBJECTIVE")
print(len(objective_texts))
print(objective_sents.shape)
subjective = go.Scatter(
                x = subjective_sents[:, 0], 
                y = subjective_sents[:, 1], 
                mode = 'markers',
                text = subjective_texts,
                hoverinfo = text, 
                marker = go.Marker(
                            color = 'red', 
                            size = 4
                ),
                name = 'Subjective'
            )
objective = go.Scatter(
                x = objective_sents[:, 0], 
                y = objective_sents[:, 1], 
                mode = 'markers',
                text = objective_texts, 
                hoverinfo = text, 
                marker = go.Marker(
                            color = 'blue', 
                            size = 4
                ),
                name = 'Objective'
            )

data = [subjective, objective]

layout = go.Layout(
    title = "t-SNE for perplexity: {}".format(p),
    hovermode = 'closest',
    xaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    ),
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    )
)

fig = go.Figure(data = data, layout = layout)
print('here')

# Plot and embed in ipython notebook!
py.iplot(fig, filename = 'Subjectivity Representations')
# Out:
# SUBJECTIVE
# 2933
# (2933, 2)
# OBJECTIVE
# 5311
# (5311, 2)
# here
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~siddsach/20.embed" height="525px" width="100%"></iframe>

# %%
p = 45
d = reduced_data[p]
subjective_inds = trained_model['train_weights']['preds'].nonzero()
subjective_inds = subjective_inds
subjective_sents = np.squeeze(d[subjective_inds])
objective_inds = (trained_model['train_weights']['preds'] == 0).nonzero()
objective_inds = objective_inds
objective_sents = np.squeeze(d[objective_inds])

texts = [' '.join(l) for l in words]
subjective_texts = [text for i, text in enumerate(texts) if torch.sum(subjective_inds == i)]
objective_texts = [text for i, text in enumerate(texts) if torch.sum(objective_inds == i)]

print("SUBJECTIVE")
print(len(subjective_texts))
print(subjective_sents.shape)
print("OBJECTIVE")
print(len(objective_texts))
print(objective_sents.shape)
subjective = go.Scatter(
                x = subjective_sents[:, 0], 
                y = subjective_sents[:, 1], 
                mode = 'markers',
                text = subjective_texts,
                hoverinfo = text, 
                marker = go.Marker(
                            color = 'red', 
                            size = 4
                ),
                name = 'Subjective'
            )
objective = go.Scatter(
                x = objective_sents[:, 0], 
                y = objective_sents[:, 1], 
                mode = 'markers',
                text = objective_texts, 
                hoverinfo = text, 
                marker = go.Marker(
                            color = 'blue', 
                            size = 4
                ),
                name = 'Objective'
            )

data = [subjective, objective]

layout = go.Layout(
    title = "t-SNE for perplexity: {}".format(p),
    hovermode = 'closest',
    xaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    ),
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    )
)

fig = go.Figure(data = data, layout = layout)
print('here')

# Plot and embed in ipython notebook!
py.iplot(fig, filename = 'Subjectivity Representations')
# Out:
# SUBJECTIVE
# 2933
# (2933, 2)
# OBJECTIVE
# 5311
# (5311, 2)
# here
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~siddsach/20.embed" height="525px" width="100%"></iframe>

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

perplexities = range(55,75, 10)

reduced_data = {}

for p in perplexities:
    
    print('Training T-SNE on hidden states for perplexity:{}...'.format(p))
    reducer = TSNE(n_components = 3, perplexity = p)
    reduced_data[p] = reducer.fit_transform(hiddens)
# Out:
# Training T-SNE on hidden states for perplexity:55...
# Training T-SNE on hidden states for perplexity:65...

# %%
p = 55
d = reduced_data[p]
subjective_inds = trained_model['train_weights']['preds'].nonzero()
subjective_inds = subjective_inds
subjective_sents = np.squeeze(d[subjective_inds])
objective_inds = (trained_model['train_weights']['preds'] == 0).nonzero()
objective_inds = objective_inds
objective_sents = np.squeeze(d[objective_inds])

texts = [' '.join(l) for l in words]
subjective_texts = [text for i, text in enumerate(texts) if torch.sum(subjective_inds == i)]
objective_texts = [text for i, text in enumerate(texts) if torch.sum(objective_inds == i)]

print("SUBJECTIVE")
print(len(subjective_texts))
print(subjective_sents.shape)
print("OBJECTIVE")
print(len(objective_texts))
print(objective_sents.shape)
subjective = go.Scatter3d(
                x = subjective_sents[:, 0], 
                y = subjective_sents[:, 1], 
                z = subjective_sents[:, 2], 
                mode = 'markers',
                text = subjective_texts,
                hoverinfo = 'text', 
                marker = go.Marker(
                            color = 'red', 
                            size = 2
                ),
                name = 'Subjective'
            )
objective = go.Scatter3d(
                x = objective_sents[:, 0], 
                y = objective_sents[:, 1], 
                z = objective_sents[:, 2], 
                mode = 'markers',
                text = objective_texts, 
                hoverinfo = 'text', 
                marker = go.Marker(
                            color = 'blue', 
                            size = 2
                ),
                name = 'Objective'
            )

data = [subjective, objective]

layout = go.Layout(
    title = "t-SNE for perplexity: {}".format(p),
    hovermode = 'closest',
    xaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    ),
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        autotick=True,
        ticks='',
        showticklabels=False
    )
)

fig = go.Figure(data = data, layout = layout)
print('here')

# Plot and embed in ipython notebook!
py.iplot(fig, filename = 'Subjectivity Representations')
# Out:
# SUBJECTIVE
# 2933
# (2933, 3)
# OBJECTIVE
# 5311
# (5311, 3)
# here
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~siddsach/20.embed" height="525px" width="100%"></iframe>
